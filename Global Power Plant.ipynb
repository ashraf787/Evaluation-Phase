# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.simplefilter('ignore')

# %%
df=pd.read_csv('Global Power Plant.csv')

# %%
df.head(25)
# Out:
#    country country_long                      name   gppd_idnr  capacity_mw  \
# 0      IND        India          ACME Solar Tower  WRI1020239         2.50
# 1      IND        India       ADITYA CEMENT WORKS  WRI1019881        98.00
# 2      IND        India  AES Saurashtra Windfarms  WRI1026669        39.20
# 3      IND        India               AGARTALA GT  IND0000001       135.00
# 4      IND        India              AKALTARA TPP  IND0000002      1800.00
# 5      IND        India              AKRIMOTA LIG  IND0000003       250.00
# 6      IND        India                    ALIYAR  IND0000004        60.00
# 7      IND        India           ALLAIN DUHANGAN  IND0000005       192.00
# 8      IND        India               ALMATTI DAM  IND0000006       290.00
# 9      IND        India               AMAR KANTAK  IND0000007       210.00
# 10     IND        India             AMARAVATI TPP  IND0000008      1350.00
# 11     IND        India    ANANDPUR SAHIB ST-I&II  IND0000009       134.00
# 12     IND        India               ANAPARA "C"  IND0000010      1200.00
# 13     IND        India                    ANDHRA  IND0000011        16.95
# 14     IND        India         ANOOPGARH ST I&II  IND0000012         9.00
# 15     IND        India                    ANPARA  IND0000013      2630.00
# 16     IND        India                   ANTA GT  IND0000014       419.33
# 17     IND        India                   ANUPPUR  WRI1019996       600.00
# 18     IND        India                ANUPUR TPP  IND0000015      1200.00
# 19     IND        India         ARVINDNAGAR SUGAR  WRI1019938        10.00
# 20     IND        India           ASHOKNAGAR MILL  WRI1019939        17.00
# 21     IND        India              ATHANI SUGAR  WRI1019904        24.00
# 22     IND        India                AURAIYA GT  IND0000016       652.00
# 23     IND        India       AVANTHA BHANDAR TPP  IND0000017       600.00
# 24     IND        India      AWARPUR CEMENT PLANT  WRI1019940        46.00
#
#     latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0    28.1839    73.2407        Solar         NaN         NaN  ...
# 1    24.7663    74.6090         Coal         NaN         NaN  ...
# 2    21.9038    69.3732         Wind         NaN         NaN  ...
# 3    23.8712    91.3602          Gas         NaN         NaN  ...
# 4    21.9603    82.4091         Coal         Oil         NaN  ...
# 5    23.7689    68.6447         Coal         Oil         NaN  ...
# 6    10.4547    77.0078        Hydro         NaN         NaN  ...
# 7    32.2258    77.2070        Hydro         NaN         NaN  ...
# 8    16.3300    75.8863        Hydro         NaN         NaN  ...
# 9    23.1642    81.6373         Coal         Oil         NaN  ...
# 10   21.0782    77.9009         Coal         Oil         NaN  ...
# 11   31.2717    76.4938        Hydro         NaN         NaN  ...
# 12   24.2007    82.8000         Coal         Oil         NaN  ...
# 13   31.2412    77.8769        Hydro         NaN         NaN  ...
# 14       NaN        NaN        Hydro         NaN         NaN  ...
# 15   24.2010    82.7891         Coal         Oil         NaN  ...
# 16   25.1797    76.3188          Gas         NaN         NaN  ...
# 17   23.0666    81.7841         Coal         NaN         NaN  ...
# 18   23.0655    81.7865         Coal         Oil         NaN  ...
# 19   18.0845    76.1851      Biomass         NaN         NaN  ...
# 20   19.5867    74.7061      Biomass         NaN         NaN  ...
# 21   16.7708    74.9191      Biomass         NaN         NaN  ...
# 22   26.6282    79.5286          Gas         NaN         NaN  ...
# 23   21.7438    83.2741         Coal         Oil         NaN  ...
# 24   19.7881    79.1518         Coal         NaN         NaN  ...
#
#     year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                     NaN                  NaN                 NaN
# 1                     NaN                  NaN                 NaN
# 2                     NaN                  NaN                 NaN
# 3                  2019.0                  NaN          617.789264
# 4                  2019.0                  NaN         3035.550000
# 5                  2019.0                  NaN         1153.421000
# 6                  2019.0                  NaN          157.558250
# 7                  2019.0                  NaN          674.391100
# 8                  2019.0                  NaN          480.594950
# 9                  2019.0                  NaN         1887.904000
# 10                 2019.0                  NaN         1920.971000
# 11                 2019.0                  NaN          614.412500
# 12                 2019.0                  NaN         7744.000000
# 13                 2019.0                  NaN                 NaN
# 14                 2019.0                  NaN                 NaN
# 15                 2019.0                  NaN         9670.879000
# 16                 2019.0                  NaN         1611.987000
# 17                    NaN                  NaN                 NaN
# 18                 2019.0                  NaN                 NaN
# 19                    NaN                  NaN                 NaN
# 20                    NaN                  NaN                 NaN
# 21                    NaN                  NaN                 NaN
# 22                 2019.0                  NaN         1607.000000
# 23                 2019.0                  NaN            0.000000
# 24                    NaN                  NaN                 NaN
#
#    generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3           843.747000          886.004428          663.774500
# 4          5916.370000         6243.000000         5385.579736
# 5          1208.852000         1175.765000         1147.913000
# 6           152.195200           61.421350           89.629600
# 7           721.335200          675.724400          679.594950
# 8           144.434200          402.029750          439.372100
# 9          1643.046000         1338.093000         1563.457000
# 10         5629.663000         1701.008000         4350.558000
# 11          665.197300          670.500650          644.570950
# 12         8076.810500         7902.021600         7940.740000
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15        11151.069472        13227.352350        15334.876300
# 16          909.000000          666.420000          430.000000
# 17                 NaN                 NaN                 NaN
# 18         2702.823200         3515.749600         5777.120000
# 19                 NaN                 NaN                 NaN
# 20                 NaN                 NaN                 NaN
# 21                 NaN                 NaN                 NaN
# 22         1465.000000          509.000000          357.000000
# 23          986.247350          283.200000          540.290000
# 24                 NaN                 NaN                 NaN
#
#     generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                   NaN                  NaN                            NaN
# 1                   NaN                  NaN                            NaN
# 2                   NaN                  NaN                            NaN
# 3            626.239128                  NaN  Central Electricity Authority
# 4           7279.000000                  NaN  Central Electricity Authority
# 5            976.655000                  NaN  Central Electricity Authority
# 6             48.327150                  NaN  Central Electricity Authority
# 7            579.318850                  NaN  Central Electricity Authority
# 8            406.377900                  NaN  Central Electricity Authority
# 9           1487.880000                  NaN  Central Electricity Authority
# 10          3717.154000                  NaN  Central Electricity Authority
# 11           425.641100                  NaN  Central Electricity Authority
# 12          7873.973000                  NaN  Central Electricity Authority
# 13                  NaN                  NaN                            NaN
# 14                  NaN                  NaN                            NaN
# 15         18697.655900                  NaN  Central Electricity Authority
# 16           528.280000                  NaN  Central Electricity Authority
# 17                  NaN                  NaN                            NaN
# 18          6241.801000                  NaN  Central Electricity Authority
# 19                  NaN                  NaN                            NaN
# 20                  NaN                  NaN                            NaN
# 21                  NaN                  NaN                            NaN
# 22           521.000000                  NaN  Central Electricity Authority
# 23             0.000000                  NaN  Central Electricity Authority
# 24                  NaN                  NaN                            NaN
#
#     estimated_generation_gwh
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
#
# [25 rows x 27 columns]

# %% [markdown]
# # Problem Statement:-The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.

# %% [markdown]
# # Target Variable:- Primary Fuel,capacity_mw

# %%
df.shape
# Out:
# (907, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
#  13  source                    907 non-null    object
#  14  url                       907 non-null    object
#  15  geolocation_source        888 non-null    object
#  16  wepp_id                   0 non-null      float64
#  17  year_of_capacity_data     519 non-null    float64
#  18  generation_gwh_2013       0 non-null      float64
#  19  generation_gwh_2014       398 non-null    float64
#  20  generation_gwh_2015       422 non-null    float64
#  21  generation_gwh_2016       434 non-null    float64
#  22  generation_gwh_2017       440 non-null    float64
#  23  generation_gwh_2018       448 non-null    float64
#  24  generation_gwh_2019       0 non-null      float64
#  25  generation_data_source    449 non-null    object
#  26  estimated_generation_gwh  0 non-null      float64
# dtypes: float64(15), object(12)
# memory usage: 191.4+ KB

# %%
df.groupby('primary_fuel')['country_long'].value_counts()
# Out:
# primary_fuel  country_long
# Biomass       India            50
# Coal          India           258
# Gas           India            69
# Hydro         India           251
# Nuclear       India             9
# Oil           India            20
# Solar         India           127
# Wind          India           123
# Name: country_long, dtype: int64

# %%
df.isna().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# # Observation:- Found some empty columns

# %%
## Removing Empty columns
df.drop(columns=['estimated_generation_gwh','generation_gwh_2019','generation_gwh_2013','wepp_id','other_fuel2','other_fuel3','url'],axis=1,inplace=True)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0            2.5   28.1839    73.2407        Solar         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil
# ..           ...       ...        ...          ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil
# 903          3.0   12.8932    78.1654        Solar         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN
#
#      commissioning_year                                owner  \
# 0                2011.0                          Solar Paces
# 1                   NaN                 Ultratech Cement ltd
# 2                   NaN                                  AES
# 3                2004.0                                  NaN
# 4                2015.0                                  NaN
# ..                  ...                                  ...
# 902              2016.0                                  NaN
# 903                 NaN  Karnataka Power Corporation Limited
# 904                 NaN                                  NaN
# 905                 NaN                   Hindustan Zinc ltd
# 906                 NaN                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                        geolocation_source  year_of_capacity_data  \
# 0    National Renewable Energy Laboratory                    NaN
# 1                                     WRI                    NaN
# 2                                     WRI                    NaN
# 3                                     WRI                 2019.0
# 4                                     WRI                 2019.0
# ..                                    ...                    ...
# 902                                   WRI                 2019.0
# 903                        Industry About                    NaN
# 904                                   WRI                    NaN
# 905                                   WRI                    NaN
# 906                                   WRI                    NaN
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             617.789264           843.747000           886.004428
# 4            3035.550000          5916.370000          6243.000000
# ..                   ...                  ...                  ...
# 902                  NaN             0.994875           233.596650
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2017  generation_gwh_2018         generation_data_source
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             663.774500           626.239128  Central Electricity Authority
# 4            5385.579736          7279.000000  Central Electricity Authority
# ..                   ...                  ...                            ...
# 902           865.400000           686.500000  Central Electricity Authority
# 903                  NaN                  NaN                            NaN
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
#
# [907 rows x 20 columns]

# %%
df.T
# Out:
#                                                          0    \
# country                                                  IND
# country_long                                           India
# name                                        ACME Solar Tower
# gppd_idnr                                         WRI1020239
# capacity_mw                                              2.5
# latitude                                             28.1839
# longitude                                            73.2407
# primary_fuel                                           Solar
# other_fuel1                                              NaN
# commissioning_year                                    2011.0
# owner                                            Solar Paces
# source                  National Renewable Energy Laboratory
# geolocation_source      National Renewable Energy Laboratory
# year_of_capacity_data                                    NaN
# generation_gwh_2014                                      NaN
# generation_gwh_2015                                      NaN
# generation_gwh_2016                                      NaN
# generation_gwh_2017                                      NaN
# generation_gwh_2018                                      NaN
# generation_data_source                                   NaN
#
#                                          1                         2    \
# country                                  IND                       IND
# country_long                           India                     India
# name                     ADITYA CEMENT WORKS  AES Saurashtra Windfarms
# gppd_idnr                         WRI1019881                WRI1026669
# capacity_mw                             98.0                      39.2
# latitude                             24.7663                   21.9038
# longitude                             74.609                   69.3732
# primary_fuel                            Coal                      Wind
# other_fuel1                              NaN                       NaN
# commissioning_year                       NaN                       NaN
# owner                   Ultratech Cement ltd                       AES
# source                  Ultratech Cement ltd                       CDM
# geolocation_source                       WRI                       WRI
# year_of_capacity_data                    NaN                       NaN
# generation_gwh_2014                      NaN                       NaN
# generation_gwh_2015                      NaN                       NaN
# generation_gwh_2016                      NaN                       NaN
# generation_gwh_2017                      NaN                       NaN
# generation_gwh_2018                      NaN                       NaN
# generation_data_source                   NaN                       NaN
#
#                                                   3    \
# country                                           IND
# country_long                                    India
# name                                      AGARTALA GT
# gppd_idnr                                  IND0000001
# capacity_mw                                     135.0
# latitude                                      23.8712
# longitude                                     91.3602
# primary_fuel                                      Gas
# other_fuel1                                       NaN
# commissioning_year                             2004.0
# owner                                             NaN
# source                  Central Electricity Authority
# geolocation_source                                WRI
# year_of_capacity_data                          2019.0
# generation_gwh_2014                        617.789264
# generation_gwh_2015                           843.747
# generation_gwh_2016                        886.004428
# generation_gwh_2017                          663.7745
# generation_gwh_2018                        626.239128
# generation_data_source  Central Electricity Authority
#
#                                                   4    \
# country                                           IND
# country_long                                    India
# name                                     AKALTARA TPP
# gppd_idnr                                  IND0000002
# capacity_mw                                    1800.0
# latitude                                      21.9603
# longitude                                     82.4091
# primary_fuel                                     Coal
# other_fuel1                                       Oil
# commissioning_year                             2015.0
# owner                                             NaN
# source                  Central Electricity Authority
# geolocation_source                                WRI
# year_of_capacity_data                          2019.0
# generation_gwh_2014                           3035.55
# generation_gwh_2015                           5916.37
# generation_gwh_2016                            6243.0
# generation_gwh_2017                       5385.579736
# generation_gwh_2018                            7279.0
# generation_data_source  Central Electricity Authority
#
#                                                   5    \
# country                                           IND
# country_long                                    India
# name                                     AKRIMOTA LIG
# gppd_idnr                                  IND0000003
# capacity_mw                                     250.0
# latitude                                      23.7689
# longitude                                     68.6447
# primary_fuel                                     Coal
# other_fuel1                                       Oil
# commissioning_year                             2005.0
# owner                                             NaN
# source                  Central Electricity Authority
# geolocation_source                                WRI
# year_of_capacity_data                          2019.0
# generation_gwh_2014                          1153.421
# generation_gwh_2015                          1208.852
# generation_gwh_2016                          1175.765
# generation_gwh_2017                          1147.913
# generation_gwh_2018                           976.655
# generation_data_source  Central Electricity Authority
#
#                                                   6    \
# country                                           IND
# country_long                                    India
# name                                           ALIYAR
# gppd_idnr                                  IND0000004
# capacity_mw                                      60.0
# latitude                                      10.4547
# longitude                                     77.0078
# primary_fuel                                    Hydro
# other_fuel1                                       NaN
# commissioning_year                             1970.0
# owner                                             NaN
# source                  Central Electricity Authority
# geolocation_source                                WRI
# year_of_capacity_data                          2019.0
# generation_gwh_2014                         157.55825
# generation_gwh_2015                          152.1952
# generation_gwh_2016                          61.42135
# generation_gwh_2017                           89.6296
# generation_gwh_2018                          48.32715
# generation_data_source  Central Electricity Authority
#
#                                                   7    \
# country                                           IND
# country_long                                    India
# name                                  ALLAIN DUHANGAN
# gppd_idnr                                  IND0000005
# capacity_mw                                     192.0
# latitude                                      32.2258
# longitude                                      77.207
# primary_fuel                                    Hydro
# other_fuel1                                       NaN
# commissioning_year                             2010.0
# owner                                             NaN
# source                  Central Electricity Authority
# geolocation_source                                WRI
# year_of_capacity_data                          2019.0
# generation_gwh_2014                          674.3911
# generation_gwh_2015                          721.3352
# generation_gwh_2016                          675.7244
# generation_gwh_2017                         679.59495
# generation_gwh_2018                         579.31885
# generation_data_source  Central Electricity Authority
#
#                                                   8    \
# country                                           IND
# country_long                                    India
# name                                      ALMATTI DAM
# gppd_idnr                                  IND0000006
# capacity_mw                                     290.0
# latitude                                        16.33
# longitude                                     75.8863
# primary_fuel                                    Hydro
# other_fuel1                                       NaN
# commissioning_year                             2004.0
# owner                                             NaN
# source                  Central Electricity Authority
# geolocation_source                                WRI
# year_of_capacity_data                          2019.0
# generation_gwh_2014                         480.59495
# generation_gwh_2015                          144.4342
# generation_gwh_2016                         402.02975
# generation_gwh_2017                          439.3721
# generation_gwh_2018                          406.3779
# generation_data_source  Central Electricity Authority
#
#                                                   9    ...  \
# country                                           IND  ...
# country_long                                    India  ...
# name                                      AMAR KANTAK  ...
# gppd_idnr                                  IND0000007  ...
# capacity_mw                                     210.0  ...
# latitude                                      23.1642  ...
# longitude                                     81.6373  ...
# primary_fuel                                     Coal  ...
# other_fuel1                                       Oil  ...
# commissioning_year                             2008.0  ...
# owner                                             NaN  ...
# source                  Central Electricity Authority  ...
# geolocation_source                                WRI  ...
# year_of_capacity_data                          2019.0  ...
# generation_gwh_2014                          1887.904  ...
# generation_gwh_2015                          1643.046  ...
# generation_gwh_2016                          1338.093  ...
# generation_gwh_2017                          1563.457  ...
# generation_gwh_2018                           1487.88  ...
# generation_data_source  Central Electricity Authority  ...
#
#                                                                       897  \
# country                                                               IND
# country_long                                                        India
# name                    Wind power project by Riddhi Siddhi Gluco Biol...
# gppd_idnr                                                      WRI1026753
# capacity_mw                                                         34.65
# latitude                                                           8.8709
# longitude                                                         77.4466
# primary_fuel                                                         Wind
# other_fuel1                                                           NaN
# commissioning_year                                                    NaN
# owner                                   Riddhi Siddhi Gluco Biols Limited
# source                                                                CDM
# geolocation_source                                                    WRI
# year_of_capacity_data                                                 NaN
# generation_gwh_2014                                                   NaN
# generation_gwh_2015                                                   NaN
# generation_gwh_2016                                                   NaN
# generation_gwh_2017                                                   NaN
# generation_gwh_2018                                                   NaN
# generation_data_source                                                NaN
#
#                                                     898  \
# country                                             IND
# country_long                                      India
# name                    Wind power project in Rajasthan
# gppd_idnr                                    WRI1026769
# capacity_mw                                        42.0
# latitude                                        27.1715
# longitude                                       70.6877
# primary_fuel                                       Wind
# other_fuel1                                         NaN
# commissioning_year                                  NaN
# owner                     Mytrah Energy (India) Limited
# source                                              CDM
# geolocation_source                                  WRI
# year_of_capacity_data                               NaN
# generation_gwh_2014                                 NaN
# generation_gwh_2015                                 NaN
# generation_gwh_2016                                 NaN
# generation_gwh_2017                                 NaN
# generation_gwh_2018                                 NaN
# generation_data_source                              NaN
#
#                                                   899  \
# country                                           IND
# country_long                                    India
# name                                  YAMUNANAGAR TPP
# gppd_idnr                                  IND0000511
# capacity_mw                                     600.0
# latitude                                      30.1081
# longitude                                     77.3257
# primary_fuel                                     Coal
# other_fuel1                                       Oil
# commissioning_year                             2007.0
# owner                                             NaN
# source                  Central Electricity Authority
# geolocation_source                                WRI
# year_of_capacity_data                          2019.0
# generation_gwh_2014                        3194.35982
# generation_gwh_2015                         3709.5522
# generation_gwh_2016                       3123.572061
# generation_gwh_2017                       3156.053669
# generation_gwh_2018                        3039.66118
# generation_data_source  Central Electricity Authority
#
#                                             900  \
# country                                     IND
# country_long                              India
# name                         YASHWANTRAO MOHITE
# gppd_idnr                            WRI1019995
# capacity_mw                                16.0
# latitude                                17.1653
# longitude                               74.2456
# primary_fuel                            Biomass
# other_fuel1                                 NaN
# commissioning_year                          NaN
# owner                   Yashwantrao Krishna ssk
# source                  Yashwantrao Krishna ssk
# geolocation_source                          WRI
# year_of_capacity_data                       NaN
# generation_gwh_2014                         NaN
# generation_gwh_2015                         NaN
# generation_gwh_2016                         NaN
# generation_gwh_2017                         NaN
# generation_gwh_2018                         NaN
# generation_data_source                      NaN
#
#                                                   901  \
# country                                           IND
# country_long                                    India
# name                                    YELHANKA (DG)
# gppd_idnr                                  IND0000512
# capacity_mw                                     106.6
# latitude                                      13.1156
# longitude                                     77.5838
# primary_fuel                                      Oil
# other_fuel1                                       NaN
# commissioning_year                             1993.0
# owner                                             NaN
# source                  Central Electricity Authority
# geolocation_source                                WRI
# year_of_capacity_data                          2019.0
# generation_gwh_2014                               0.0
# generation_gwh_2015                               0.0
# generation_gwh_2016                               0.0
# generation_gwh_2017                               NaN
# generation_gwh_2018                               0.0
# generation_data_source  Central Electricity Authority
#
#                                                   902  \
# country                                           IND
# country_long                                    India
# name                                     YERMARUS TPP
# gppd_idnr                                  IND0000513
# capacity_mw                                    1600.0
# latitude                                      16.2949
# longitude                                     77.3568
# primary_fuel                                     Coal
# other_fuel1                                       Oil
# commissioning_year                             2016.0
# owner                                             NaN
# source                  Central Electricity Authority
# geolocation_source                                WRI
# year_of_capacity_data                          2019.0
# generation_gwh_2014                               NaN
# generation_gwh_2015                          0.994875
# generation_gwh_2016                         233.59665
# generation_gwh_2017                             865.4
# generation_gwh_2018                             686.5
# generation_data_source  Central Electricity Authority
#
#                                                         903  \
# country                                                 IND
# country_long                                          India
# name                           Yelesandra Solar Power Plant
# gppd_idnr                                        WRI1026222
# capacity_mw                                             3.0
# latitude                                            12.8932
# longitude                                           78.1654
# primary_fuel                                          Solar
# other_fuel1                                             NaN
# commissioning_year                                      NaN
# owner                   Karnataka Power Corporation Limited
# source                  Karnataka Power Corporation Limited
# geolocation_source                           Industry About
# year_of_capacity_data                                   NaN
# generation_gwh_2014                                     NaN
# generation_gwh_2015                                     NaN
# generation_gwh_2016                                     NaN
# generation_gwh_2017                                     NaN
# generation_gwh_2018                                     NaN
# generation_data_source                                  NaN
#
#                                                  904                 905  \
# country                                          IND                 IND
# country_long                                   India               India
# name                    Yelisirur wind power project         ZAWAR MINES
# gppd_idnr                                 WRI1026776          WRI1019901
# capacity_mw                                     25.5                80.0
# latitude                                     15.2758               24.35
# longitude                                    75.5811             73.7477
# primary_fuel                                    Wind                Coal
# other_fuel1                                      NaN                 NaN
# commissioning_year                               NaN                 NaN
# owner                                            NaN  Hindustan Zinc ltd
# source                                           CDM  Hindustan Zinc ltd
# geolocation_source                               WRI                 WRI
# year_of_capacity_data                            NaN                 NaN
# generation_gwh_2014                              NaN                 NaN
# generation_gwh_2015                              NaN                 NaN
# generation_gwh_2016                              NaN                 NaN
# generation_gwh_2017                              NaN                 NaN
# generation_gwh_2018                              NaN                 NaN
# generation_data_source                           NaN                 NaN
#
#                                             906
# country                                     IND
# country_long                              India
# name                    iEnergy Theni Wind Farm
# gppd_idnr                            WRI1026761
# capacity_mw                                16.5
# latitude                                 9.9344
# longitude                               77.4768
# primary_fuel                               Wind
# other_fuel1                                 NaN
# commissioning_year                          NaN
# owner                        iEnergy Wind Farms
# source                                      CDM
# geolocation_source                          WRI
# year_of_capacity_data                       NaN
# generation_gwh_2014                         NaN
# generation_gwh_2015                         NaN
# generation_gwh_2016                         NaN
# generation_gwh_2017                         NaN
# generation_gwh_2018                         NaN
# generation_data_source                      NaN
#
# [20 rows x 907 columns]

# %%
df.isna().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                   46
# longitude                  46
# primary_fuel                0
# other_fuel1               709
# commissioning_year        380
# owner                     565
# source                      0
# geolocation_source         19
# year_of_capacity_data     388
# generation_gwh_2014       509
# generation_gwh_2015       485
# generation_gwh_2016       473
# generation_gwh_2017       467
# generation_gwh_2018       459
# generation_data_source    458
# dtype: int64

# %%
df['geolocation_source'].unique()
# Out:
# array(['National Renewable Energy Laboratory', 'WRI', nan,
#        'Industry About'], dtype=object)

# %%
df.nunique()
# Out:
# country                     1
# country_long                1
# name                      907
# gppd_idnr                 907
# capacity_mw               361
# latitude                  836
# longitude                 827
# primary_fuel                8
# other_fuel1                 3
# commissioning_year         73
# owner                     280
# source                    191
# geolocation_source          3
# year_of_capacity_data       1
# generation_gwh_2014       371
# generation_gwh_2015       396
# generation_gwh_2016       403
# generation_gwh_2017       408
# generation_gwh_2018       410
# generation_data_source      1
# dtype: int64

# %%
df['generation_data_source'].unique()
# Out:
# array([nan, 'Central Electricity Authority'], dtype=object)

# %%
df['year_of_capacity_data'].unique()
# Out:
# array([  nan, 2019.])

# %% [markdown]
# # Observation:- Year and generation shows irrelevant to proceed for model,so dropping these two column.

# %%
df.drop(columns=['generation_data_source','year_of_capacity_data'],axis=1,inplace=True)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0            2.5   28.1839    73.2407        Solar         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil
# ..           ...       ...        ...          ...         ...
# 902       1600.0   16.2949    77.3568         Coal         Oil
# 903          3.0   12.8932    78.1654        Solar         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN
#
#      commissioning_year                                owner  \
# 0                2011.0                          Solar Paces
# 1                   NaN                 Ultratech Cement ltd
# 2                   NaN                                  AES
# 3                2004.0                                  NaN
# 4                2015.0                                  NaN
# ..                  ...                                  ...
# 902              2016.0                                  NaN
# 903                 NaN  Karnataka Power Corporation Limited
# 904                 NaN                                  NaN
# 905                 NaN                   Hindustan Zinc ltd
# 906                 NaN                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                        geolocation_source  generation_gwh_2014  \
# 0    National Renewable Energy Laboratory                  NaN
# 1                                     WRI                  NaN
# 2                                     WRI                  NaN
# 3                                     WRI           617.789264
# 4                                     WRI          3035.550000
# ..                                    ...                  ...
# 902                                   WRI                  NaN
# 903                        Industry About                  NaN
# 904                                   WRI                  NaN
# 905                                   WRI                  NaN
# 906                                   WRI                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3             626.239128
# 4            7279.000000
# ..                   ...
# 902           686.500000
# 903                  NaN
# 904                  NaN
# 905                  NaN
# 906                  NaN
#
# [907 rows x 18 columns]

# %%
df.drop(columns=['country','country_long','gppd_idnr'],axis=1,inplace=True)

# %%
df
# Out:
#                              name  capacity_mw  latitude  longitude  \
# 0                ACME Solar Tower          2.5   28.1839    73.2407
# 1             ADITYA CEMENT WORKS         98.0   24.7663    74.6090
# 2        AES Saurashtra Windfarms         39.2   21.9038    69.3732
# 3                     AGARTALA GT        135.0   23.8712    91.3602
# 4                    AKALTARA TPP       1800.0   21.9603    82.4091
# ..                            ...          ...       ...        ...
# 902                  YERMARUS TPP       1600.0   16.2949    77.3568
# 903  Yelesandra Solar Power Plant          3.0   12.8932    78.1654
# 904  Yelisirur wind power project         25.5   15.2758    75.5811
# 905                   ZAWAR MINES         80.0   24.3500    73.7477
# 906       iEnergy Theni Wind Farm         16.5    9.9344    77.4768
#
#     primary_fuel other_fuel1  commissioning_year  \
# 0          Solar         NaN              2011.0
# 1           Coal         NaN                 NaN
# 2           Wind         NaN                 NaN
# 3            Gas         NaN              2004.0
# 4           Coal         Oil              2015.0
# ..           ...         ...                 ...
# 902         Coal         Oil              2016.0
# 903        Solar         NaN                 NaN
# 904         Wind         NaN                 NaN
# 905         Coal         NaN                 NaN
# 906         Wind         NaN                 NaN
#
#                                    owner  \
# 0                            Solar Paces
# 1                   Ultratech Cement ltd
# 2                                    AES
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 902                                  NaN
# 903  Karnataka Power Corporation Limited
# 904                                  NaN
# 905                   Hindustan Zinc ltd
# 906                   iEnergy Wind Farms
#
#                                    source  \
# 0    National Renewable Energy Laboratory
# 1                    Ultratech Cement ltd
# 2                                     CDM
# 3           Central Electricity Authority
# 4           Central Electricity Authority
# ..                                    ...
# 902         Central Electricity Authority
# 903   Karnataka Power Corporation Limited
# 904                                   CDM
# 905                    Hindustan Zinc ltd
# 906                                   CDM
#
#                        geolocation_source  generation_gwh_2014  \
# 0    National Renewable Energy Laboratory                  NaN
# 1                                     WRI                  NaN
# 2                                     WRI                  NaN
# 3                                     WRI           617.789264
# 4                                     WRI          3035.550000
# ..                                    ...                  ...
# 902                                   WRI                  NaN
# 903                        Industry About                  NaN
# 904                                   WRI                  NaN
# 905                                   WRI                  NaN
# 906                                   WRI                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
#
#      generation_gwh_2018
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3             626.239128
# 4            7279.000000
# ..                   ...
# 902           686.500000
# 903                  NaN
# 904                  NaN
# 905                  NaN
# 906                  NaN
#
# [907 rows x 15 columns]

# %%
# Lets impute missing values
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
df1=df[['capacity_mw','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','generation_gwh_2018']]

# %%
imputed=IterativeImputer(random_state=42)
imp=imputed.fit_transform(df1)

# %%
df2=pd.DataFrame(imp,columns=df1.columns)

# %%
df['generation_gwh_2014']=df2['generation_gwh_2014']
df['generation_gwh_2015']=df2['generation_gwh_2015']
df['generation_gwh_2016']=df2['generation_gwh_2016']
df['generation_gwh_2017']=df2['generation_gwh_2017']
df['generation_gwh_2018']=df2['generation_gwh_2018']

# %%
df.isna().sum()
# Out:
# name                     0
# capacity_mw              0
# latitude                46
# longitude               46
# primary_fuel             0
# other_fuel1            709
# commissioning_year     380
# owner                  565
# source                   0
# geolocation_source      19
# generation_gwh_2014      0
# generation_gwh_2015      0
# generation_gwh_2016      0
# generation_gwh_2017      0
# generation_gwh_2018      0
# dtype: int64

# %%
df['latitude']=df['latitude'].fillna(df['latitude'].mean())
df['longitude']=df['longitude'].fillna(df['longitude'].mean())
df['geolocation_source']=df['geolocation_source'].fillna(df['geolocation_source'].mode()[0])
df['commissioning_year']=df['commissioning_year'].fillna(df['commissioning_year'].median())

# %%
df.isnull().sum()
# Out:
# name                     0
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# other_fuel1            709
# commissioning_year       0
# owner                  565
# source                   0
# geolocation_source       0
# generation_gwh_2014      0
# generation_gwh_2015      0
# generation_gwh_2016      0
# generation_gwh_2017      0
# generation_gwh_2018      0
# dtype: int64

# %%
df.drop(columns=['other_fuel1','owner'],axis=1,inplace=True)

# %%
df
# Out:
#                              name  capacity_mw  latitude  longitude  \
# 0                ACME Solar Tower          2.5   28.1839    73.2407
# 1             ADITYA CEMENT WORKS         98.0   24.7663    74.6090
# 2        AES Saurashtra Windfarms         39.2   21.9038    69.3732
# 3                     AGARTALA GT        135.0   23.8712    91.3602
# 4                    AKALTARA TPP       1800.0   21.9603    82.4091
# ..                            ...          ...       ...        ...
# 902                  YERMARUS TPP       1600.0   16.2949    77.3568
# 903  Yelesandra Solar Power Plant          3.0   12.8932    78.1654
# 904  Yelisirur wind power project         25.5   15.2758    75.5811
# 905                   ZAWAR MINES         80.0   24.3500    73.7477
# 906       iEnergy Theni Wind Farm         16.5    9.9344    77.4768
#
#     primary_fuel  commissioning_year                                source  \
# 0          Solar              2011.0  National Renewable Energy Laboratory
# 1           Coal              2001.0                  Ultratech Cement ltd
# 2           Wind              2001.0                                   CDM
# 3            Gas              2004.0         Central Electricity Authority
# 4           Coal              2015.0         Central Electricity Authority
# ..           ...                 ...                                   ...
# 902         Coal              2016.0         Central Electricity Authority
# 903        Solar              2001.0   Karnataka Power Corporation Limited
# 904         Wind              2001.0                                   CDM
# 905         Coal              2001.0                    Hindustan Zinc ltd
# 906         Wind              2001.0                                   CDM
#
#                        geolocation_source  generation_gwh_2014  \
# 0    National Renewable Energy Laboratory          1288.670952
# 1                                     WRI          1431.720928
# 2                                     WRI          1343.644084
# 3                                     WRI           617.789264
# 4                                     WRI          3035.550000
# ..                                    ...                  ...
# 902                                   WRI           446.714974
# 903                        Industry About          1289.419905
# 904                                   WRI          1323.122778
# 905                                   WRI          1404.758629
# 906                                   WRI          1309.641629
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0            1342.448818          1186.373783          1064.675602
# 1            1492.108378          1372.923956          1285.774710
# 2            1399.961968          1258.063745          1149.642484
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 902             0.994875           233.596650           865.400000
# 903          1343.232375          1187.350486          1065.833189
# 904          1378.492481          1231.302097          1117.924602
# 905          1463.900294          1337.762667          1244.101580
# 906          1364.388439          1213.721453          1097.088037
#
#      generation_gwh_2018
# 0             925.269267
# 1            1182.793896
# 2            1024.234229
# 3             626.239128
# 4            7279.000000
# ..                   ...
# 902           686.500000
# 903           926.617563
# 904           987.290905
# 905          1134.255222
# 906           963.021568
#
# [907 rows x 13 columns]

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   907.000000  907.000000  907.000000          907.000000
# mean    326.223755   21.197918   77.464907         1998.728776
# std     590.085456    6.079148    4.812291           13.158621
# min       0.000000    8.168900   68.644700         1927.000000
# 25%      16.725000   17.072000   74.388900         1998.000000
# 50%      59.200000   21.281800   76.979200         2001.000000
# 75%     385.250000   25.176450   79.206100         2003.000000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# count           907.000000           907.000000           907.000000
# mean           1773.578548          1849.761436          1818.737371
# std            2748.972481          2928.820019          2951.021323
# min            -627.793950          -743.690999             0.000000
# 25%             665.933600           664.038125           703.619225
# 50%            1301.702730          1357.336418          1210.791345
# 75%            1360.420626          1419.629272          1316.665894
# max           28127.000000         30539.000000         30015.000000
#
#        generation_gwh_2017  generation_gwh_2018
# count           907.000000           907.000000
# mean           1814.152392          1798.220471
# std            3014.506369          3140.272186
# min             -77.227020          -171.843616
# 25%             804.900275           810.733240
# 50%            1093.615276           961.673272
# 75%            1255.990270          1185.086000
# max           35116.000000         35136.000000

# %%
df.columns
# Out:
# Index(['name', 'capacity_mw', 'latitude', 'longitude', 'primary_fuel',
#        'commissioning_year', 'source', 'geolocation_source',
#        'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016',
#        'generation_gwh_2017', 'generation_gwh_2018'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %% [markdown]
# # Observation:- Coal and hydropower plant is more as compared to other fuel

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='geolocation_source',data=df)
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
sns.relplot(x='generation_gwh_2014',y='capacity_mw',kind='line',data=df)

# %%
plt.figure(figsize=(15,8))
sns.relplot(x='generation_gwh_2015',y='capacity_mw',kind='line',hue='primary_fuel',style='primary_fuel',data=df)

# %%
plt.figure(figsize=(15,8))
sns.relplot(x='generation_gwh_2016',y='capacity_mw',kind='line',hue='primary_fuel',style='primary_fuel',data=df)

# %%
plt.figure(figsize=(15,8))
sns.relplot(x='generation_gwh_2017',y='capacity_mw',kind='line',hue='primary_fuel',data=df)

# %%
plt.figure(figsize=(15,8))
sns.relplot(x='generation_gwh_2018',y='capacity_mw',kind='line',hue='primary_fuel',data=df)

# %% [markdown]
# # Observation:- In all the plot the electricity generated by coal powerplant in all years is higher than other powerplant

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='primary_fuel',y='latitude',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='latitude'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='primary_fuel',y='longitude',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='longitude'>

# %% [markdown]
# # Observation:- Primary fuel coal,hydro and solar has high longitude and latitude

# %%
plt.style.use('ggplot')
plt.figure(figsize=(15,7))
sns.lineplot(x='primary_fuel',y='latitude',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='latitude'>

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='primary_fuel',y='longitude',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='longitude'>

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='primary_fuel',y='capacity_mw',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='capacity_mw'>

# %% [markdown]
# # Observation:- The study shows that the nuclear and coal producing high electrical energy.

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='primary_fuel',y='commissioning_year',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='commissioning_year'>

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x='primary_fuel',y='geolocation_source',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='geolocation_source'>

# %% [markdown]
# # Pair Plot

# %%
plt.figure(figsize=(15,15))
sns.pairplot(df)

# %% [markdown]
# # Observation:- Plot show capacity growth is linearly dependent on generation_gwh

# %%
## Importing label encoder
from sklearn.preprocessing import LabelEncoder

# %%
lm=LabelEncoder()

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 902    False
# 903    False
# 904    False
# 905    False
# 906    False
# Length: 907, dtype: bool

# %%
categorial_variable=['primary_fuel','source','geolocation_source']
df[categorial_variable]=df[categorial_variable].apply(lm.fit_transform)

# %%
df
# Out:
#                              name  capacity_mw  latitude  longitude  \
# 0                ACME Solar Tower          2.5   28.1839    73.2407
# 1             ADITYA CEMENT WORKS         98.0   24.7663    74.6090
# 2        AES Saurashtra Windfarms         39.2   21.9038    69.3732
# 3                     AGARTALA GT        135.0   23.8712    91.3602
# 4                    AKALTARA TPP       1800.0   21.9603    82.4091
# ..                            ...          ...       ...        ...
# 902                  YERMARUS TPP       1600.0   16.2949    77.3568
# 903  Yelesandra Solar Power Plant          3.0   12.8932    78.1654
# 904  Yelisirur wind power project         25.5   15.2758    75.5811
# 905                   ZAWAR MINES         80.0   24.3500    73.7477
# 906       iEnergy Theni Wind Farm         16.5    9.9344    77.4768
#
#      primary_fuel  commissioning_year  source  geolocation_source  \
# 0               6              2011.0     109                   1
# 1               1              2001.0     174                   2
# 2               7              2001.0      21                   2
# 3               2              2004.0      22                   2
# 4               1              2015.0      22                   2
# ..            ...                 ...     ...                 ...
# 902             1              2016.0      22                   2
# 903             6              2001.0      77                   0
# 904             7              2001.0      21                   2
# 905             1              2001.0      59                   2
# 906             7              2001.0      21                   2
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0            1288.670952          1342.448818          1186.373783
# 1            1431.720928          1492.108378          1372.923956
# 2            1343.644084          1399.961968          1258.063745
# 3             617.789264           843.747000           886.004428
# 4            3035.550000          5916.370000          6243.000000
# ..                   ...                  ...                  ...
# 902           446.714974             0.994875           233.596650
# 903          1289.419905          1343.232375          1187.350486
# 904          1323.122778          1378.492481          1231.302097
# 905          1404.758629          1463.900294          1337.762667
# 906          1309.641629          1364.388439          1213.721453
#
#      generation_gwh_2017  generation_gwh_2018
# 0            1064.675602           925.269267
# 1            1285.774710          1182.793896
# 2            1149.642484          1024.234229
# 3             663.774500           626.239128
# 4            5385.579736          7279.000000
# ..                   ...                  ...
# 902           865.400000           686.500000
# 903          1065.833189           926.617563
# 904          1117.924602           987.290905
# 905          1244.101580          1134.255222
# 906          1097.088037           963.021568
#
# [907 rows x 13 columns]

# %%
df.drop('name',axis=1,inplace=True)

# %%
df
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407             6              2011.0
# 1           98.0   24.7663    74.6090             1              2001.0
# 2           39.2   21.9038    69.3732             7              2001.0
# 3          135.0   23.8712    91.3602             2              2004.0
# 4         1800.0   21.9603    82.4091             1              2015.0
# ..           ...       ...        ...           ...                 ...
# 902       1600.0   16.2949    77.3568             1              2016.0
# 903          3.0   12.8932    78.1654             6              2001.0
# 904         25.5   15.2758    75.5811             7              2001.0
# 905         80.0   24.3500    73.7477             1              2001.0
# 906         16.5    9.9344    77.4768             7              2001.0
#
#      source  geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0       109                   1          1288.670952          1342.448818
# 1       174                   2          1431.720928          1492.108378
# 2        21                   2          1343.644084          1399.961968
# 3        22                   2           617.789264           843.747000
# 4        22                   2          3035.550000          5916.370000
# ..      ...                 ...                  ...                  ...
# 902      22                   2           446.714974             0.994875
# 903      77                   0          1289.419905          1343.232375
# 904      21                   2          1323.122778          1378.492481
# 905      59                   2          1404.758629          1463.900294
# 906      21                   2          1309.641629          1364.388439
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# 0            1186.373783          1064.675602           925.269267
# 1            1372.923956          1285.774710          1182.793896
# 2            1258.063745          1149.642484          1024.234229
# 3             886.004428           663.774500           626.239128
# 4            6243.000000          5385.579736          7279.000000
# ..                   ...                  ...                  ...
# 902           233.596650           865.400000           686.500000
# 903          1187.350486          1065.833189           926.617563
# 904          1231.302097          1117.924602           987.290905
# 905          1337.762667          1244.101580          1134.255222
# 906          1213.721453          1097.088037           963.021568
#
# [907 rows x 12 columns]

# %%
plt.figure(figsize=(20,20),facecolor='pink')
plotnumber=1

for column in df:
    if plotnumber <= 12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
plt.figure(figsize=(20,20),facecolor='pink')
plotnumber=1

for column in df:
    if plotnumber <= 12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column],color='r')
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %% [markdown]
# # Observation:- 1. Outlier found 2. skewness in the data

# %%
## Removing Outlier through zscore
from scipy.stats import zscore
df=df[np.abs(zscore(df)<3).all(axis=1)]

# %%
df.shape
# Out:
# (852, 12)

# %%
data_loss=907-852
print((data_loss/907)*100)
# Out:
# 6.063947078280044

# %% [markdown]
# # Since 6 % data_loss we concluded so we can proceed

# %%
df.skew()
# Out:
# capacity_mw            1.997844
# latitude              -0.109981
# longitude              0.925439
# primary_fuel           0.423184
# commissioning_year    -1.718919
# source                 1.818830
# geolocation_source    -2.140211
# generation_gwh_2014    2.661899
# generation_gwh_2015    2.470095
# generation_gwh_2016    2.543754
# generation_gwh_2017    2.489654
# generation_gwh_2018    2.570453
# dtype: float64

# %%
# Separting Target variable and features
X=df.drop('primary_fuel',axis=1)
y=df.primary_fuel

# %%
## Importing powertransformer
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()

# %%
x=pd.DataFrame(pt.fit_transform(X),columns=X.columns)

# %%
x
# Out:
#      capacity_mw  latitude  longitude  commissioning_year    source  \
# 0      -1.678080  1.153338  -0.941274            1.119749  1.634724
# 1       0.229427  0.590793  -0.523612            0.067138  2.109191
# 2      -0.269219  0.122919  -2.370549            0.067138 -0.462731
# 3       0.402434  0.444148   2.432670            0.358029 -0.393796
# 4       1.759759  0.132122   1.239137            1.612920 -0.393796
# ..           ...       ...        ...                 ...       ...
# 847     1.699814 -0.783616   0.204297            1.743400 -0.393796
# 848    -1.598754 -1.325424   0.393871            0.067138  1.249376
# 849    -0.503638 -0.946644  -0.250257            0.067138 -0.462731
# 850     0.119377  0.522553  -0.781799            0.067138  0.934129
# 851    -0.739513 -1.790491   0.233085            0.067138 -0.462731
#
#      geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0             -2.322383             0.005301            -0.016965
# 1              0.398946             0.112285             0.088210
# 2              0.398946             0.046838             0.023773
# 3              0.398946            -0.561142            -0.391123
# 4              0.398946             1.146936             2.602564
# ..                  ...                  ...                  ...
# 847            0.398946            -0.733574            -1.270353
# 848           -2.512703             0.005871            -0.016407
# 849            0.398946             0.031397             0.008614
# 850            0.398946             0.092389             0.068589
# 851            0.398946             0.021212            -0.001375
#
#      generation_gwh_2016  generation_gwh_2017  generation_gwh_2018
# 0               0.101110            -0.074703            -0.180197
# 1               0.240883             0.092945             0.013004
# 2               0.156404            -0.008597            -0.103890
# 3              -0.157697            -0.424922            -0.431431
# 4               2.203378             2.140869             2.922697
# ..                   ...                  ...                  ...
# 847            -1.053556            -0.239672            -0.377792
# 848             0.101878            -0.073787            -0.179138
# 849             0.136008            -0.033012            -0.132048
# 850             0.215526             0.062392            -0.022139
# 851             0.122453            -0.049218            -0.150754
#
# [852 rows x 11 columns]

# %%
x.skew()
# Out:
# capacity_mw            0.014804
# latitude              -0.073608
# longitude             -0.002018
# commissioning_year    -0.547000
# source                -0.192768
# geolocation_source    -2.111830
# generation_gwh_2014    0.755797
# generation_gwh_2015    0.807803
# generation_gwh_2016    0.026304
# generation_gwh_2017    0.400119
# generation_gwh_2018    0.573718
# dtype: float64

# %%
plt.figure(figsize=(20,20),facecolor='pink')
plotnumber=1

for column in x:
    if plotnumber <= 12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(x[column])
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
plt.figure(figsize=(20,20),facecolor='pink')
plotnumber=1

for column in x:
    if plotnumber <= 12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(x[column],color='r')
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,annot_kws={'size':10})
plt.show()

# %%
# lets operate the multicolinearity problem through Variance inflation factor
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_scaled.shape[1]
# Out:
# 11

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['feature']=x.columns

# %%
vif
# Out:
#           vif              feature
# 0    2.059620          capacity_mw
# 1    1.085120             latitude
# 2    1.198587            longitude
# 3    1.172676   commissioning_year
# 4    1.246946               source
# 5    1.599262   geolocation_source
# 6    6.916983  generation_gwh_2014
# 7    9.572692  generation_gwh_2015
# 8    9.564484  generation_gwh_2016
# 9   28.933965  generation_gwh_2017
# 10  20.369375  generation_gwh_2018

# %%
vif.mean()
# Out:
# vif    7.610883
# dtype: float64

# %% [markdown]
# # Observation:- from vif and skewness we found vif>10 is generation_gwh_2017,generation_gwh_2018 has multicolinearity problem.

# %% [markdown]
# # Also geolocation_source is too much negatively skewed, so dropping these columns

# %%
x.drop(columns=['generation_gwh_2017','generation_gwh_2018','geolocation_source'],axis=1,inplace=True)

# %%
x
# Out:
#      capacity_mw  latitude  longitude  commissioning_year    source  \
# 0      -1.678080  1.153338  -0.941274            1.119749  1.634724
# 1       0.229427  0.590793  -0.523612            0.067138  2.109191
# 2      -0.269219  0.122919  -2.370549            0.067138 -0.462731
# 3       0.402434  0.444148   2.432670            0.358029 -0.393796
# 4       1.759759  0.132122   1.239137            1.612920 -0.393796
# ..           ...       ...        ...                 ...       ...
# 847     1.699814 -0.783616   0.204297            1.743400 -0.393796
# 848    -1.598754 -1.325424   0.393871            0.067138  1.249376
# 849    -0.503638 -0.946644  -0.250257            0.067138 -0.462731
# 850     0.119377  0.522553  -0.781799            0.067138  0.934129
# 851    -0.739513 -1.790491   0.233085            0.067138 -0.462731
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016
# 0               0.005301            -0.016965             0.101110
# 1               0.112285             0.088210             0.240883
# 2               0.046838             0.023773             0.156404
# 3              -0.561142            -0.391123            -0.157697
# 4               1.146936             2.602564             2.203378
# ..                   ...                  ...                  ...
# 847            -0.733574            -1.270353            -1.053556
# 848             0.005871            -0.016407             0.101878
# 849             0.031397             0.008614             0.136008
# 850             0.092389             0.068589             0.215526
# 851             0.021212            -0.001375             0.122453
#
# [852 rows x 8 columns]

# %%
plt.figure(figsize=(15,7))
x.corrwith(y).plot(kind='bar',grid=True,title='correlation with target')
# Out:
# <AxesSubplot:title={'center':'correlation with target'}>

# %%
## Model Building
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# DecisionTree
dt=DecisionTreeClassifier()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=41)

# %%
def model(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        ypred=clf.predict(x_train)
        print('  Training Result  ')
        print('Accuracy_Score: ',accuracy_score(y_train,ypred)*100)
        
    elif train==False:
        y_pred=clf.predict(x_test)
        print('   Test Result    ')
        print('Accuracy_Score: ',accuracy_score(y_test,y_pred)*100)
        print(confusion_matrix(y_test,y_pred))
        print(classification_report(y_test,y_pred))

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model(dt,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  100.0

# %%
model(dt,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  75.11737089201877
# [[ 5  1  0  0  0  0  1  0]
#  [ 3 41  2  5  0  0  2  0]
#  [ 0  6  9  4  0  0  1  0]
#  [ 0  7  3 47  0  4  0  0]
#  [ 0  3  0  1  0  0  0  0]
#  [ 0  0  1  2  0  2  0  0]
#  [ 2  5  0  0  0  0 26  0]
#  [ 0  0  0  0  0  0  0 30]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.71      0.59         7
#            1       0.65      0.77      0.71        53
#            2       0.60      0.45      0.51        20
#            3       0.80      0.77      0.78        61
#            4       0.00      0.00      0.00         4
#            5       0.33      0.40      0.36         5
#            6       0.87      0.79      0.83        33
#            7       1.00      1.00      1.00        30
#
#     accuracy                           0.75       213
#    macro avg       0.59      0.61      0.60       213
# weighted avg       0.75      0.75      0.75       213

# %% [markdown]
# # RandomForest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model(rf,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  100.0

# %%
model(rf,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  79.34272300469483
# [[ 5  2  0  0  0  0  0  0]
#  [ 4 40  1  5  0  0  3  0]
#  [ 1  5 10  4  0  0  0  0]
#  [ 1  5  0 55  0  0  0  0]
#  [ 0  3  0  1  0  0  0  0]
#  [ 0  0  3  0  0  2  0  0]
#  [ 1  4  0  0  0  0 28  0]
#  [ 0  0  0  0  0  0  1 29]]
#               precision    recall  f1-score   support
#
#            0       0.42      0.71      0.53         7
#            1       0.68      0.75      0.71        53
#            2       0.71      0.50      0.59        20
#            3       0.85      0.90      0.87        61
#            4       0.00      0.00      0.00         4
#            5       1.00      0.40      0.57         5
#            6       0.88      0.85      0.86        33
#            7       1.00      0.97      0.98        30
#
#     accuracy                           0.79       213
#    macro avg       0.69      0.64      0.64       213
# weighted avg       0.79      0.79      0.79       213

# %%
gbdt=GradientBoostingClassifier()
gbdt.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
model(gbdt,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  100.0

# %%
model(gbdt,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  79.34272300469483
# [[ 6  1  0  0  0  0  0  0]
#  [ 5 39  1  5  0  0  3  0]
#  [ 0  4  8  4  1  2  1  0]
#  [ 0  5  0 56  0  0  0  0]
#  [ 0  2  1  1  0  0  0  0]
#  [ 0  0  3  1  0  1  0  0]
#  [ 1  3  0  0  0  0 29  0]
#  [ 0  0  0  0  0  0  0 30]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.86      0.63         7
#            1       0.72      0.74      0.73        53
#            2       0.62      0.40      0.48        20
#            3       0.84      0.92      0.88        61
#            4       0.00      0.00      0.00         4
#            5       0.33      0.20      0.25         5
#            6       0.88      0.88      0.88        33
#            7       1.00      1.00      1.00        30
#
#     accuracy                           0.79       213
#    macro avg       0.61      0.62      0.61       213
# weighted avg       0.78      0.79      0.78       213

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
print('RandomForest',cross_val_score(rf,x,y,cv=5).mean())
print('DecisionTree',cross_val_score(dt,x,y,cv=5).mean())
print('GradientBoosting',cross_val_score(gbdt,x,y,cv=5).mean())
# Out:
# RandomForest 0.8134021327829377
# DecisionTree 0.7758651530787753
# GradientBoosting 0.820405916752666

# %%
## Lets check distance based algorithm
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
x_scaled=scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=41)

# %% [markdown]
# # SVM

# %%
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
model(svc,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  77.77777777777779

# %%
model(svc,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  71.83098591549296
# [[ 4  2  0  0  0  0  0  1]
#  [ 2 40  0  5  0  0  3  3]
#  [ 2  7  4  7  0  0  0  0]
#  [ 0  5  0 50  0  0  0  6]
#  [ 0  3  0  1  0  0  0  0]
#  [ 0  0  1  4  0  0  0  0]
#  [ 3  3  0  0  0  0 25  2]
#  [ 0  0  0  0  0  0  0 30]]
#               precision    recall  f1-score   support
#
#            0       0.36      0.57      0.44         7
#            1       0.67      0.75      0.71        53
#            2       0.80      0.20      0.32        20
#            3       0.75      0.82      0.78        61
#            4       0.00      0.00      0.00         4
#            5       0.00      0.00      0.00         5
#            6       0.89      0.76      0.82        33
#            7       0.71      1.00      0.83        30
#
#     accuracy                           0.72       213
#    macro avg       0.52      0.51      0.49       213
# weighted avg       0.71      0.72      0.69       213

# %% [markdown]
# # KNN

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model(knn,x_train,x_test,y_train,y_test,train=True)
# Out:
#   Training Result
# Accuracy_Score:  83.8810641627543

# %%
model(knn,x_train,x_test,y_train,y_test,train=False)
# Out:
#    Test Result
# Accuracy_Score:  73.23943661971832
# [[ 4  2  0  0  0  0  0  1]
#  [ 4 40  2  3  0  0  1  3]
#  [ 0  6  7  5  0  2  0  0]
#  [ 0  4  1 48  0  1  0  7]
#  [ 0  3  0  1  0  0  0  0]
#  [ 0  0  1  3  0  1  0  0]
#  [ 4  2  1  0  0  0 26  0]
#  [ 0  0  0  0  0  0  0 30]]
#               precision    recall  f1-score   support
#
#            0       0.33      0.57      0.42         7
#            1       0.70      0.75      0.73        53
#            2       0.58      0.35      0.44        20
#            3       0.80      0.79      0.79        61
#            4       0.00      0.00      0.00         4
#            5       0.25      0.20      0.22         5
#            6       0.96      0.79      0.87        33
#            7       0.73      1.00      0.85        30
#
#     accuracy                           0.73       213
#    macro avg       0.55      0.56      0.54       213
# weighted avg       0.73      0.73      0.72       213

# %%
print('SVM',cross_val_score(svc,x,y,cv=5).mean())
print('KNN',cross_val_score(knn,x,y,cv=5).mean())
# Out:
# SVM 0.7429308565531476
# KNN 0.7746336429308565

# %% [markdown]
# # GradientBoosting and Random Forest gives high accuracy,so lets do the hyperparameter tuning

# %%
params={'learning_rate':[0.1,0.01,1,0.2,0.002],
       'n_estimators':[100],
       'min_samples_split':[3,4,5,6,7,8],
       'min_samples_leaf':[1,2,3,4,5,6],
       'max_depth':[3,4,5,6,7,8,9]}

# %%
gv=GridSearchCV(gbdt,param_grid=params,cv=5,n_jobs=-1)

# %%
gv.fit(x_train,y_train)

# %%
gv.best_params_

# %%
gbdt=GradientBoostingClassifier(learning_rate=0.1,max_depth=3,min_samples_leaf=3,min_samples_split=7,n_estimators=100)

# %%
gbdt.fit(x_train,y_train)

# %%
model(gbdt,x_train,x_test,y_train,y_test,train=True)

# %%
model(gbdt,x_train,x_test,y_train,y_test,train=False)

# %%
print('GradientBoosting',cross_val_score(gbdt,x,y,cv=5).mean())

# %% [markdown]
# # Hyperparameter Tuning Of RandomForest

# %%
params={'criterion':['gini','entropy'],
       'n_estimators':[100],
       'min_samples_split':[3,4,5,6,7,8],
       'min_samples_leaf':[1,2,3,4,5,6],
       'max_depth':[3,4,5,6,7,8,9]}

# %%
gv=GridSearchCV(rf,param_grid=params,n_jobs=-1)
gv.fit(x_train,y_train)

# %%
gv.best_params_

# %%
rf=RandomForestClassifier(criterion='gini',max_depth=10,min_samples_leaf=6,min_samples_split=3,n_estimators=100)
rf.fit(x_train,y_train)

# %%
model(rf,x_train,x_test,y_train,y_test,train=True)

# %%
model(rf,x_train,x_test,y_train,y_test,train=False)

# %% [markdown]
# # Conclusion:-Gradient boosting is the final model with accuracy of 82% and the best parameter is learning_rate=0.1,max_depth=3,min_samples_leaf=3,min_samples_split=7,n_estimators=100

# %%
model(gbdt,x_train,x_test,y_train,y_test,train=False)

# %%
y_pred=gbdt.predict(x_test)

# %%
Report=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})

# %%
Report

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(y_test,y_pred,hue=y_pred,palette="deep")
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()

# %% [markdown]
# # Saving the model

# %%
import pickle
filename='PrimaryFuel'
pickle.dump(gbdt,open(filename,'wb'))

# %% [markdown]
# # Regression

# %%
df

# %% [markdown]
# # Target Variable-capacity_mw

# %%
# Separting target variable and Features
X=df.drop('capacity_mw',axis=1)
y=df.capacity_mw

# %%
plt.figure(figsize=(20,20),facecolor='lightblue')
plotnumber=1

for column in X:
    if plotnumber <= 12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(X[column],color='r')
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %%
X.skew()

# %%
# Reducing skewness through PowerTransformer
x=pd.DataFrame(pt.fit_transform(X),columns=X.columns)

# %%
plt.figure(figsize=(20,20),facecolor='lightblue')
plotnumber=1

for column in x:
    if plotnumber <= 12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(x[column],color='r')
        plt.xlabel(column,fontsize=14)
    plotnumber=plotnumber+1
    
plt.tight_layout()

# %% [markdown]
# # Observation:- Based on skewness dropping geolocation_source column

# %%
x.drop('geolocation_source',axis=1,inplace=True)

# %%
plt.figure(figsize=(15,7))
sns.heatmap(x.corr(),annot=True,annot_kws={'size':10})
plt.show()

# %%
x_scaled=scaler.fit_transform(x)

# %%
x_scaled.shape[1]

# %%
vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif['features']=x.columns
vif

# %% [markdown]
# # Observation:- Since multicollinearity exist in two columns which is >10,so dropping these two columns..

# %%
x.drop(columns=['generation_gwh_2017','generation_gwh_2018'],axis=1,inplace=True)

# %%
# Model building
x_scaled=scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=41)

# %%
from sklearn.linear_model import LinearRegression,Lasso,LassoCV,Ridge,RidgeCV
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
def model(clf,x_train,x_test,y_train,y_test,train=True):
    if train:
        ypred=clf.predict(x_train)
        print('Traning r2_score: ',r2_score(y_train,ypred)*100)
    elif train==False:
        y_pred=clf.predict(x_test)
        print('The testing Score-',r2_score(y_test,y_pred)*100)
        print('MSE: ',mean_squared_error(y_test,y_pred))
        print('MAE: ',mean_absolute_error(y_test,y_pred))
        print('RMSE ',np.sqrt(mean_squared_error(y_test,y_pred)))

# %% [markdown]
# # LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)

# %%
model(lr,x_train,x_test,y_train,y_test,train=True)

# %%
model(lr,x_train,x_test,y_train,y_test,train=False)

# %%
# Regularization
## Ridge Regression through through cross_validation
ridgecv=RidgeCV(alphas=(0.1,1,10,0.01,0.002),cv=10,normalize=True)
ridgecv.fit(x_train,y_train)

# %%
ridgecv.alpha_

# %%
ridge=Ridge(alpha=0.1)
ridge.fit(x_train,y_train)

# %%
model(ridge,x_train,x_test,y_train,y_test,train=True)

# %%
model(ridge,x_train,x_test,y_train,y_test,train=False)

# %%
## LASSO Regression
lassocv=LassoCV(cv=10,max_iter=10000,normalize=True)
lassocv.fit(x_train,y_train)

# %%
lassocv.alpha_

# %%
lasso=Lasso(alpha=lassocv.alpha_)
lasso.fit(x_train,y_train)

# %%
model(lasso,x_train,x_test,y_train,y_test,train=True)

# %%
model(lasso,x_train,x_test,y_train,y_test,train=False)

# %% [markdown]
# # Random Forest

# %%
rd=RandomForestRegressor()
rd.fit(x_train,y_train)

# %%
model(rd,x_train,x_test,y_train,y_test,train=True)

# %%
model(rd,x_train,x_test,y_train,y_test,train=False)

# %% [markdown]
# # SVM

# %%
svr=SVR()
svr.fit(x_train,y_train)

# %%
model(svr,x_train,x_test,y_train,y_test,train=True)

# %%
model(svr,x_train,x_test,y_train,y_test,train=False)

# %% [markdown]
# # xgboost

# %%
xgb=XGBRegressor()
xgb.fit(x_train,y_train)

# %%
model(xgb,x_train,x_test,y_train,y_test,train=True)

# %%
model(xgb,x_train,x_test,y_train,y_test,train=False)

# %% [markdown]
# # KNN

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)

# %%
model(knn,x_train,x_test,y_train,y_test,train=True)

# %%
model(knn,x_train,x_test,y_train,y_test,train=False)

# %%
# Hyperparameter Tunning
params={'n_estimators':[100],
       'criterion':['squared_error'],
       'max_depth':[1,2,3,4,5,6,7,8,9],
       'min_samples_split':[1,2,3,4,5,6,7,8],
       'min_samples_leaf':[3,4,5,7,8]}

# %%
gv=GridSearchCV(rd,param_grid=params,n_jobs=-1)
gv.fit(x_train,y_train)

# %%
gv.best_params_

# %%
rd=RandomForestRegressor(criterion='squared_error',max_depth=9,min_samples_leaf=3,min_samples_split=8,n_estimators=100)

# %%
rd.fit(x_train,y_train)

# %%
model(rd,x_train,x_test,y_train,y_test,train=True)

# %%
model(rd,x_train,x_test,y_train,y_test,train=False)

# %%
print(cross_val_score(rd,x_scaled,y,cv=5).mean())

# %% [markdown]
# # Final Conclusion:- Random Forest give good accuracy and cross_val_ score

# %%
y_pred=rd.predict(x_test)

# %%
Report=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
